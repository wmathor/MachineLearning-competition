# %% [markdown]
# ## 制作第一个BaseLine
# 算法的研发：迭代的过程
#
# BaseLine -> V0.1.0 -> V0.2.0...
#
# 数据读入 -> 数据处理 -> 训练集/评测集制作 -> 机器学习 -> 模型评测( -> 模型集成 -> 应用开发)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('data/train.csv') #训练集的获取

# %%
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
train.get_dtype_counts()
# Out:
# float64     3
# int64      35
# object     43
# dtype: int64

# %%
train1 = train # 拷贝数据

# %% [markdown]
# ----

# %% [markdown]
# ## 数据的简单填充

# %% [markdown]
# ### Numerical
# 1. 均值填充
# 2. 中位数
# 3. 函数填充（需要和数据集中某些列产生函数映射关系）

# %%
empty = train.isnull().sum()
empty = empty[empty > 0]
empty.shape
# Out:
# (19,)

# %%
#均值填充
train1 = train1.fillna(train1.mean()) # 填充平均值

# %% [markdown]
# ### Categorial填充
# 1. 控制填充【增加一个"None"-"NA"】
#
# 2. 高频填充
#
# 3. 关系填充【根据数据的含义，参考其他的列进行填充】

# %%
train1 = train1.fillna("None")

# %%
def getNullCount(t):
    enpty = t.isnull().sum()
    print(enpty[enpty > 0])

# %%
getNullCount(train1)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# 至此，已经完成了暴力填充

# %% [markdown]
# -----

# %% [markdown]
# ## 训练集的制作

# %%
y = train1['SalePrice']
train1 = train1.drop(['Id' ,'SalePrice'], axis = 1)

# %%
train1.head(10)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL    65.000000     8450   Pave  None      Reg
# 1          20       RL    80.000000     9600   Pave  None      Reg
# 2          60       RL    68.000000    11250   Pave  None      IR1
# 3          70       RL    60.000000     9550   Pave  None      IR1
# 4          60       RL    84.000000    14260   Pave  None      IR1
# 5          50       RL    85.000000    14115   Pave  None      IR1
# 6          20       RL    75.000000    10084   Pave  None      Reg
# 7          60       RL    70.049958    10382   Pave  None      IR1
# 8          50       RM    51.000000     6120   Pave  None      Reg
# 9         190       RL    50.000000     7420   Pave  None      Reg
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0   None
# ...

# %%
x = pd.get_dummies(train1).reset_index(drop = True) # one_hot

# %%
x.head(10)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60    65.000000     8450            7            5       2003
# 1          20    80.000000     9600            6            8       1976
# 2          60    68.000000    11250            7            5       2001
# 3          70    60.000000     9550            7            5       1915
# 4          60    84.000000    14260            8            5       2000
# 5          50    85.000000    14115            5            5       1993
# 6          20    75.000000    10084            8            5       2004
# 7          60    70.049958    10382            7            6       1973
# 8          50    51.000000     6120            7            5       1931
# 9         190    50.000000     7420            5            6       1939
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# 0          2003       196.0         706           0          ...
# ...

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import numpy as np

# %%
matrix = xgb.DMatrix(data = x,label = y)

# %%
# 数据集进行拆分，80%训练，20%用来测试
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 123)

# %%
x_train.shape
# Out:
# (1168, 303)

# %%
x_test.shape
# Out:
# (292, 303)

# %%
# XGBoost
xg_reg = xgb.XGBRegressor(objective = 'reg:linear',colsample_bytree = 0.4,learning_rate = 0.01,max_depth = 8,alpha = 10, n_estimators = 200, subsample = 0.7)

# %%
xg_reg.fit(x_train,y_train)
# Out:
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.4, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=8, min_child_weight=1, missing=None, n_estimators=200,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.7)

# %%
pred = xg_reg.predict(x_test)

# %%
pred
# Out:
# array([197395.28 , 105024.83 , 126992.37 , 202250.06 , 122510.055,
#        213211.22 , 264926.72 , 110276.54 , 124213.89 , 100890.125,
#        127221.92 , 199451.55 , 124895.59 , 107858.51 , 209615.4  ,
#        147672.44 , 126038.625, 310938.16 , 191940.55 , 142576.75 ,
#        125935.13 , 159236.25 ,  97821.64 , 125297.23 , 189948.67 ,
#        126828.055, 185043.67 , 161429.75 , 111281.984, 120911.16 ,
#        121125.73 , 176088.28 , 124599.41 , 173591.7  , 290502.25 ,
#        180720.47 , 146649.81 , 255862.44 , 145063.94 ,  82395.664,
#        116767.96 , 184961.55 , 150452.3  , 144773.45 , 184959.33 ,
#        101086.37 , 240931.1  , 186658.98 , 211036.38 , 102818.01 ,
#        166529.88 , 164270.44 , 126047.58 , 139964.11 ,  91941.63 ,
#        135620.78 , 110186.93 , 140844.72 , 201157.73 , 323865.2  ,
#         95598.13 , 293418.9  , 125165.875, 145226.84 , 186612.94 ,
#        117351.766, 101663.87 , 195942.97 , 207679.5  , 124277.12 ,
# ...

# %%
rmse = np.sqrt(mean_squared_error(np.log(y_test),np.log(pred)))

# %%
rmse
# Out:
# 0.18986113375428385
